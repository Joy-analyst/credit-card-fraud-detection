# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('creditcard.csv')

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
print (df['Class']. value_counts())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
print(df.columns)


print(df['Class'].value_counts())
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(x='Class', data=df, hue= 'Class', palette=['blue', 'pink'], edgecolor='black')
plt.title('Number of Fraud Vs Non-Fraud Cases')
plt.xlabel('Outcome (0 = Fraud, 1 = Non-Fraud)')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
outcome_counts = df['Class'].value_counts()
labels = ['No Fraud (0)', 'Fraud(1)']
plt.figure(figsize=(6, 6))
plt.pie(outcome_counts, labels=labels, autopct='%1.1f%%', colors=['blue', 'pink'], startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title('Distribution of Fraud class')
plt.axis('equal')  
plt.show()

# %%
# List of features including Outcome
features = ['V1', 'V2', 'V3', 'V4', 'V5']

# Set up the plot grid
plt.figure(figsize=(18, 14))

for i, feature in enumerate(features):
    plt.subplot(3, 3, i + 1)
    sns.boxplot(y=df[feature], color='mediumblue')
    plt.title(f'{feature} Boxplot')
    plt.ylabel(feature)
    plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

features = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8']
df_melted = df[features].melt(var_name='Feature', value_name='Value')

plt.figure(figsize=(12, 6))
sns.boxplot(x='Feature', y='Value', data=df_melted, hue='Feature', palette='Set3', legend=False)
plt.title('Boxplot of All Features')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
corr_matrix = df.corr()
plt.figure(figsize=(16, 14))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True, linewidths=0.5, linecolor='gray')
plt.title('Correlation Heatmap of Fraud Detection', fontsize=16)
plt.tight_layout()
plt.show()

# %%
min_vals = df.min()
max_vals = df.max()

scaling_check = pd.DataFrame({'Min': min_vals, 'Max': max_vals})
print(scaling_check)
# Out:
#                Min            Max
# Time      0.000000  172792.000000
# V1      -56.407510       2.454930
# V2      -72.715728      22.057729
# V3      -48.325589       9.382558
# V4       -5.683171      16.875344
# V5     -113.743307      34.801666
# V6      -26.160506      73.301626
# V7      -43.557242     120.589494
# V8      -73.216718      20.007208
# V9      -13.434066      15.594995
# V10     -24.588262      23.745136
# V11      -4.797473      12.018913
# V12     -18.683715       7.848392
# V13      -5.791881       7.126883
# V14     -19.214325      10.526766
# V15      -4.498945       8.877742
# V16     -14.129855      17.315112
# V17     -25.162799       9.253526
# V18      -9.498746       5.041069
# V19      -7.213527       5.591971
# V20     -54.497720      39.420904
# V21     -34.830382      27.202839
# V22     -10.933144      10.503090
# V23     -44.807735      22.528412
# V24      -2.836627       4.584549
# V25     -10.295397       7.519589
# ...

# %%
means = df.mean()
stds = df.std()

standard_check = pd.DataFrame({'Mean': means, 'Std Dev': stds})
print(standard_check)
# Out:
#                 Mean       Std Dev
# Time    9.481386e+04  47488.145955
# V1      1.168375e-15      1.958696
# V2      3.416908e-16      1.651309
# V3     -1.379537e-15      1.516255
# V4      2.074095e-15      1.415869
# V5      9.604066e-16      1.380247
# V6      1.487313e-15      1.332271
# V7     -5.556467e-16      1.237094
# V8      1.213481e-16      1.194353
# V9     -2.406331e-15      1.098632
# V10     2.239053e-15      1.088850
# V11     1.673327e-15      1.020713
# V12    -1.247012e-15      0.999201
# V13     8.190001e-16      0.995274
# V14     1.207294e-15      0.958596
# V15     4.887456e-15      0.915316
# V16     1.437716e-15      0.876253
# V17    -3.772171e-16      0.849337
# V18     9.564149e-16      0.838176
# V19     1.039917e-15      0.814041
# V20     6.406204e-16      0.770925
# V21     1.654067e-16      0.734524
# V22    -3.568593e-16      0.725702
# V23     2.578648e-16      0.624460
# V24     4.473266e-15      0.605647
# V25     5.340915e-16      0.521278
# ...

# %%
print(df.describe())
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
from scipy import stats

# 2. Generate Normal Data
normal_data = np.random.normal(loc=50, scale=10, size=1000)  # Mean=50, Std=10

# 3. Calculate Mean and Median
mean_normal = np.mean(normal_data)
median_normal = np.median(normal_data)

print(f"Mean of normal data: {mean_normal:.2f}")
print(f"Median of normal data: {median_normal:.2f}")

# 4. Plot Normal Distribution
plt.figure(figsize=(8, 5))
sns.histplot(normal_data, kde=True, color='skyblue', bins=30)
plt.axvline(mean_normal, color='red', linestyle='--', label='Mean')
plt.axvline(median_normal, color='green', linestyle='-', label='Median')
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# 5. Create Skewed Data
skewed_data = stats.skewnorm.rvs(a=10, loc=50, scale=10, size=1000)  # Positively skewed

# 6. Summary of Skewed Data
print("\nSkewed Data Summary:")
print(f"Mean: {np.mean(skewed_data):.2f}")
print(f"Median: {np.median(skewed_data):.2f}")
print(f"Skewness: {stats.skew(skewed_data):.2f}")

# 7. Plot Skewed Distribution
plt.figure(figsize=(8, 5))
sns.histplot(skewed_data, kde=True, color='salmon', bins=30)
plt.title('Positively Skewed Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# Show missing values count
print("\nMissing Values in Data:")
print(df.isnull().sum())
# Out:
# Mean of normal data: 50.10
# Median of normal data: 50.07
# Skewed Data Summary:
# Mean: 57.88
# Median: 56.55
# Skewness: 0.89
# Missing Values in Data:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Step 1: Define X and y
X = df.drop('Class', axis=1)
y = df['Class']

# Step 2: Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # This gives you a NumPy array

# (Optional) Convert to DataFrame if you want to keep column names
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# Step 3: Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %%
print("Training Set Shape:", X_train.shape)
print("Testing Set Shape:", X_test.shape)
# Out:
# Training Set Shape: (227845, 30)
# Testing Set Shape: (56962, 30)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print ("y_train shape:", y_train.shape)
print ("y_test shape:", y_test.shape)
# Out:
# X_train shape: (227845, 30)
# X_test shape: (56962, 30)
# y_train shape: (227845,)
# y_test shape: (56962,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# Train the model

model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#predict on test set
y_pred = model.predict(X_test)

# %%
#Evaluate performance 

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nclassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9991573329588147
#
# classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# After model.predict()
y_pred = model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_test, model.predict_proba(X_test)[:,1]))
# Out:
# [[56851    13]
#  [   35    63]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC-AUC Score: 0.9599474004570878

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[56851    13]
#  [   35    63]]

# %%
print(y_test.value_counts())
# Out:
# Class
# 0    56864
# 1       98
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
conf_mat = confusion_matrix(y_test, y_pred)

# Plot using seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1], yticklabels=[0, 1])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np

row_index = 25

# Make sure X_test is a 2D array
if isinstance(X_test, np.ndarray):
    sample = X_test[row_index].reshape(1, -1)
else:
    sample = X_test.iloc[row_index].values.reshape(1, -1)

# Predict
predicted_label = model.predict(sample)[0]
predicted_prob = model.predict_proba(sample)[0][1]

# Handle y_test as Series or array
if hasattr(y_test, 'iloc'):
    actual_label = y_test.iloc[row_index]
else:
    actual_label = y_test[row_index]

# Display results
print(f"Row {row_index} prediction: {predicted_label} (probability of class 1 = {predicted_prob:.4f})")
print(f"Actual label: {actual_label}")
# Out:
# Row 25 prediction: 0 (probability of class 1 = 0.0002)
# Actual label: 0
# C:\Users\1012 G2\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\1012 G2\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize and fit the model
xgb_model = XGBClassifier(eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)

# Predict
xgb_pred = xgb_model.predict(X_test)

# Evaluation
print("\nXGBOOST")
print("Accuracy:", accuracy_score(y_test, xgb_pred))
print("Classification Report:\n", classification_report(y_test, xgb_pred))
# Out:
# XGBOOST
# Accuracy: 0.9994382219725431
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.87      0.80      0.83        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.90      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
import joblib
joblib.dump(xgb_model,"xgb_Fraud Detection_model.pkl")
# Out:
# ['xgb_Fraud Detection_model.pkl']

# %%
joblib.dump(scaler, 'scaler.joblib')
# Out:
# ['scaler.joblib']

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\1012 G2\\DSA'
